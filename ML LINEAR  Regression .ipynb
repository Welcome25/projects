# %%


# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv( r"C:\Users\de\Downloads\Advertising (1).csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head(5)
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail(5)
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  200 non-null    int64
#  1   TV          200 non-null    float64
#  2   Radio       200 non-null    float64
#  3   Newspaper   200 non-null    float64
#  4   Sales       200 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 7.9 KB

# %%
df.describe()
# Out:
#        Unnamed: 0          TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000  200.000000
# mean   100.500000  147.042500   23.264000   30.554000   14.022500
# std     57.879185   85.854236   14.846809   21.778621    5.217457
# min      1.000000    0.700000    0.000000    0.300000    1.600000
# 25%     50.750000   74.375000    9.975000   12.750000   10.375000
# 50%    100.500000  149.750000   22.900000   25.750000   12.900000
# 75%    150.250000  218.825000   36.525000   45.100000   17.400000
# max    200.000000  296.400000   49.600000  114.000000   27.000000

# %%
df.shape
# Out:
# (200, 5)

# %%
sns.histplot(x=df.TV,data=df,kde=True)
# Out:
# <Axes: xlabel='TV', ylabel='Count'>

# %%
sns.histplot(x=df.Radio,data=df,kde=True)
# Out:
# <Axes: xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(x=df.Newspaper,data=df,kde=True)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Count'>

# %%
sns.relplot(x="TV",y="Sales",data=df)

# %%
sns.relplot(x="Newspaper",y="TV",data=df)

# %%
sns.relplot(x="Radio",y="Sales",data=df)

# %%
sns.pairplot(data=df)

# %%
df.isnull().sum()
# Out:
# Unnamed: 0    0
# TV            0
# Radio         0
# Newspaper     0
# Sales         0
# dtype: int64

# %%
sns.boxplot(x=df.TV,data=df)
# Out:
# <Axes: xlabel='TV'>

# %%
sns.boxplot(x=df.Radio,data=df)
# Out:
# <Axes: xlabel='Radio'>

# %%
sns.boxplot(x=df.Newspaper,data=df)
# Out:
# <Axes: xlabel='Newspaper'>

# %%
sns.barplot(x=df.TV,y=df.Sales,data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.barplot(x=df.Newspaper,y=df.Radio,data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Radio'>

# %%
sns.lineplot(x=df.TV,y=df.Sales,data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.barplot(x=df.Sales,y=df.Radio,data=df)
# Out:
# <Axes: xlabel='Sales', ylabel='Radio'>

# %%
df.drop(['Unnamed: 0'],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.drop(['Unnamed: 0'],axis=1,inplace=True)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5603, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5455 def drop(
#    5456     self,
#    5457     labels: IndexLabel | None = None,
#    (...)   5464     errors: IgnoreRaise = "raise",
#    5465 ) -> DataFrame | None:
#    5466     """
#    5467     Drop specified labels from rows or columns.
#    5468
#    (...)   5601             weight  1.0     0.8
#    5602     """
# -> 5603     return super().drop(
#    5604         labels=labels,
#    5605         axis=axis,
#    5606         index=index,
#    5607         columns=columns,
#    5608         level=level,
#    5609         inplace=inplace,
#    5610         errors=errors,
#    5611     )
#
# ...

# %%
df
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3    9.3
# 3    151.5   41.3       58.5   18.5
# 4    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1    9.7
# 197  177.0    9.3        6.4   12.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
x=df[['TV','Newspaper','Radio']]
y=df.Sales

# %%
x
# Out:
#         TV  Newspaper  Radio
# 0    230.1       69.2   37.8
# 1     44.5       45.1   39.3
# 2     17.2       69.3   45.9
# 3    151.5       58.5   41.3
# 4    180.8       58.4   10.8
# ..     ...        ...    ...
# 195   38.2       13.8    3.7
# 196   94.2        8.1    4.9
# 197  177.0        6.4    9.3
# 198  283.6       66.2   42.0
# 199  232.1        8.7    8.6
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 0      22.1
# 1      10.4
# 2       9.3
# 3      18.5
# 4      12.9
#        ...
# 195     7.6
# 196     9.7
# 197    12.8
# 198    25.5
# 199    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
#Training and Testing data
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train
# Out:
#         TV  Newspaper  Radio
# 79   116.0       23.1    7.7
# 197  177.0        6.4    9.3
# 38    43.1       35.1   26.7
# 24    62.3       18.3   12.6
# 122  224.0       15.6    2.4
# ..     ...        ...    ...
# 106   25.0       29.7   11.0
# 14   204.1       46.0   32.9
# 92   217.7       59.0   33.5
# 179  165.6       17.6   10.0
# 102  280.2       21.4   10.1
#
# [160 rows x 3 columns]

# %%
x_test
# Out:
#         TV  Newspaper  Radio
# 95   163.3       52.9   31.6
# 15   195.4       52.9   47.7
# 30   292.9       43.2   28.3
# 158   11.7       45.2   36.9
# 128  220.3        3.2   49.0
# 115   75.1       52.7   35.0
# 69   216.8       27.2   43.9
# 170   50.0       18.4   11.6
# 174  222.4       13.1    3.4
# 45   175.1       31.5   22.5
# 66    31.5        2.2   24.6
# 182   56.2       29.7    5.7
# 165  234.5       84.8    3.4
# 78     5.4        9.4   29.9
# 186  139.5       26.6    2.1
# 177  170.2       35.2    7.8
# 56     7.3       41.4   28.1
# 152  197.6       14.2   23.3
# 82    75.3       32.5   20.3
# 68   237.4       11.0   27.5
# 124  229.5       74.2   32.3
# 16    67.8      114.0   36.6
# 148   38.0       11.9   40.3
# 93   250.9       72.3   36.5
# 65    69.0        0.9    9.3
# 60    53.5       21.4    2.0
# 84   213.5       33.8   43.0
# 67   139.3       10.2   14.5
# 125   87.2       25.9   11.8
# 132    8.4        2.1   27.2
# 9    199.8       21.2    2.6
# ...

# %%
y_train
# Out:
# 79     11.0
# 197    12.8
# 38     10.1
# 24      9.7
# 122    11.6
#        ...
# 106     7.2
# 14     19.0
# 92     19.4
# 179    12.6
# 102    14.8
# Name: Sales, Length: 160, dtype: float64

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
from sklearn.linear_model import LinearRegression
LR=LinearRegression()

# %%
LR
# Out:
# LinearRegression()

# %%
LR.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=LR.predict(x_test)

# %%
y_pred
# Out:
# array([16.4080242 , 20.88988209, 21.55384318, 10.60850256, 22.11237326,
#        13.10559172, 21.05719192,  7.46101034, 13.60634581, 15.15506967,
#         9.04831992,  6.65328312, 14.34554487,  8.90349333,  9.68959028,
#        12.16494386,  8.73628397, 16.26507258, 10.27759582, 18.83109103,
#        19.56036653, 13.25103464, 12.33620695, 21.30695132,  7.82740305,
#         5.80957448, 20.75753231, 11.98138077,  9.18349576,  8.5066991 ,
#        12.46646769, 10.00337695, 21.3876709 , 12.24966368, 18.26661538,
#        20.13766267, 14.05514005, 20.85411186, 11.0174441 ,  4.56899622])

# %%
y_test
# Out:
# 95     16.9
# 15     22.4
# 30     21.4
# 158     7.3
# 128    24.7
# 115    12.6
# 69     22.3
# 170     8.4
# 174    11.5
# 45     14.9
# 66      9.5
# 182     8.7
# 165    11.9
# 78      5.3
# 186    10.3
# 177    11.7
# 56      5.5
# 152    16.6
# 82     11.3
# 68     18.9
# 124    19.7
# 16     12.5
# 148    10.9
# 93     22.2
# 65      9.3
# 60      8.1
# 84     21.7
# 67     13.4
# 125    10.6
# 132     5.7
# 9      10.6
# 18     11.3
# 55     23.7
# 75      8.7
# 150    16.1
# 104    20.7
# 135    11.6
# 137    20.8
# 164    11.9
# 76      6.9
# Name: Sales, dtype: float64

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error

# %%
mse=mean_squared_error(y_test,y_pred)
print("mean_squared_error",mse)
# Out:
# mean_squared_error 3.1740973539761037

# %%
LR.predict([[200,100,500]])
# Out:
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([106.79860938])
