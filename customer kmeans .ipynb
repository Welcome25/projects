# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv(r"C:\Users\de\Downloads\customer_kmeans_dataset.csv")

# %%
df
# Out:
#     Age  Annual_Income_k$  Spending_Score  Savings_k$
# 0    58                29               4          35
# 1    33                43              18          13
# 2    52                26              76          54
# 3    20                18              12          27
# 4    32                79              78           3
# ..  ...               ...             ...         ...
# 95   33                62              37          20
# 96   46                84              91          38
# 97   57               118              84          67
# 98   18               100              71          38
# 99   60                28              18          33
#
# [100 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Age               100 non-null    int64
#  1   Annual_Income_k$  100 non-null    int64
#  2   Spending_Score    100 non-null    int64
#  3   Savings_k$        100 non-null    int64
# dtypes: int64(4)
# memory usage: 3.3 KB

# %%
df.head()
# Out:
#    Age  Annual_Income_k$  Spending_Score  Savings_k$
# 0   58                29               4          35
# 1   33                43              18          13
# 2   52                26              76          54
# 3   20                18              12          27
# 4   32                79              78           3

# %%
x=df.iloc[:,1:]
x.head()
# Out:
#    Annual_Income_k$  Spending_Score  Savings_k$
# 0                29               4          35
# 1                43              18          13
# 2                26              76          54
# 3                18              12          27
# 4                79              78           3

# %%
from sklearn.cluster import KMeans
WCSS=[]
for i in range (1,20):
    kmeans=KMeans(n_clusters=i,random_state=42)
    kmeans.fit(x)
    WCSS.append(kmeans.inertia_)
plt.plot(range(1,20),WCSS)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# ...

# %%
#model building
from sklearn.cluster import KMeans
model = KMeans(n_clusters=8, random_state=42)

#Training the model
model.fit(x)
# Out:
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1419: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=1.
#   warnings.warn(
# KMeans(random_state=42)

# %%
label=model.labels_
label
# Out:
# array([3, 3, 6, 3, 2, 6, 6, 7, 3, 0, 3, 0, 4, 4, 2, 1, 3, 6, 2, 2, 4, 6,
#        5, 0, 7, 3, 0, 4, 3, 4, 4, 6, 7, 4, 1, 2, 1, 0, 1, 1, 4, 4, 3, 5,
#        4, 1, 6, 6, 5, 4, 6, 1, 2, 2, 3, 5, 3, 3, 4, 6, 4, 4, 3, 4, 2, 7,
#        0, 3, 1, 0, 5, 5, 0, 2, 3, 4, 6, 5, 3, 5, 3, 2, 7, 7, 1, 4, 6, 0,
#        5, 1, 4, 7, 5, 4, 1, 3, 5, 5, 5, 3], dtype=int32)

# %%
model.cluster_centers_
# Out:
# array([[ 99.66666667,  38.22222222,  19.        ],
#        [ 30.72727273,  64.81818182,  26.        ],
#        [ 70.2       ,  72.4       ,  20.9       ],
#        [ 39.21052632,  18.42105263,  30.42105263],
#        [ 85.63157895,  32.15789474,  63.10526316],
#        [100.69230769,  78.        ,  32.07692308],
#        [ 42.33333333,  72.08333333,  64.41666667],
#        [104.        ,   8.        ,  19.28571429]])

# %%
# Out:
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([6], dtype=int32)

# %%
new_point=[[30,40,200]] # A new observation
model.predict(new_point) # predicted label
# Out:
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
# array([6], dtype=int32)

# %%
label
# Out:
# array([3, 3, 6, 3, 2, 6, 6, 7, 3, 0, 3, 0, 4, 4, 2, 1, 3, 6, 2, 2, 4, 6,
#        5, 0, 7, 3, 0, 4, 3, 4, 4, 6, 7, 4, 1, 2, 1, 0, 1, 1, 4, 4, 3, 5,
#        4, 1, 6, 6, 5, 4, 6, 1, 2, 2, 3, 5, 3, 3, 4, 6, 4, 4, 3, 4, 2, 7,
#        0, 3, 1, 0, 5, 5, 0, 2, 3, 4, 6, 5, 3, 5, 3, 2, 7, 7, 1, 4, 6, 0,
#        5, 1, 4, 7, 5, 4, 1, 3, 5, 5, 5, 3], dtype=int32)

# %%
lowest=[]
moderate=[]
highest=[]

for i in range(len(df)):
    if label[i]==1:
        highest.append(df['Annual_Income_k$'][i])
    elif label[i]==2:
        lowest.append(df['Annual_Income_k$'][i])
    else:
        moderate.append(df['Annual_Income_k$'][i])

# %%
print("Annual_Income_k$ lowest \n",lowest)
# Out:
# Annual_Income_k$ lowest
#  [np.int64(79), np.int64(61), np.int64(62), np.int64(49), np.int64(74), np.int64(66), np.int64(81), np.int64(74), np.int64(77), np.int64(79)]

# %%
new_point=[[30,40,200]] # A new observation
newpred=model.predict(new_point) # predicted label
print(newpred)

cluster = newpred[0]

if cluster == 0:
    print("First cluster")
elif cluster == 1:
    print("Second cluster")
elif cluster == 2:
    print("Third cluster")
elif cluster == 3:
    print("Fourth cluster")
elif cluster == 4:
    print("Fifth cluster")
elif cluster == 5:
    print("Sixth cluster")
elif cluster == 6:
    print("Seventh cluster")
elif cluster == 7:
    print("Eighth cluster")
# Out:
# [6]
# Seventh cluster
# C:\Users\de\AppData\Local\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but KMeans was fitted with feature names
#   warnings.warn(
